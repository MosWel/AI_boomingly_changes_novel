# %%
import Env
from ebooklib import epub

# %% [markdown]
# ### 本段的目的是实现对.epub格式下各章节内容的定位以及读取和修改

# %%
# 读取某一卷下单个章节的数据
def get_chapter_data():
    edt = epub.read_epub(Env.DATA_PATH)
    chapter_list = edt.spine
    print(edt.get_items())
get_chapter_data()
# Out:
# <class 'list'>
# <generator object EpubBook.get_items.<locals>.<genexpr> at 0x0000026655DA5540>

# %%
# 修改某一卷下单个章节的数据

# %% [markdown]
# ### 本段的目的是实现对.epub格式下各章节图片的定位以及读取和修改
